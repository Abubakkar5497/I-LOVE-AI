# %% [markdown]
# # Pandas

# %% [markdown]
# ## Pandas -->Panel Data
# ## cleaning transforming and Analyzing the Data
# ## 2-D array format tablet (rows/columns)Excel
#
# ## components:
#
# ## 1.Series --> a representions of sequence as a column
# ## 2. DataFrame--> a collection of series or Columns

# %%
import pandas as pd

# %%
data1 = [101,102,103,104]
print(data1, type(data1))
# Out:
# [101, 102, 103, 104] <class 'list'>

# %%
f1 = pd.Series(data1)
print(data1, type(f1))
# Out:
# [101, 102, 103, 104] <class 'pandas.core.series.Series'>

# %%
f2 = pd.Series(data1)
print(f2, type(f2))
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# dtype: int64 <class 'pandas.core.series.Series'>

# %%
name1 = ['abu','parveen','ayesha','hakim']
print(name1, type(name1))

name2 = pd.Series(name1)
print(name2, type(name2))
# Out:
# ['abu', 'parveen', 'ayesha', 'hakim'] <class 'list'>
# 0        abu
# 1    parveen
# 2     ayesha
# 3      hakim
# dtype: object <class 'pandas.core.series.Series'>

# %% [markdown]
# ## Load data into dataframe from lists,series,dictionaries

# %%
df1 = pd.DataFrame({'eid':f2, 'ename':name2})
print(df1)
df1
# Out:
#    eid    ename
# 0  101      abu
# 1  102  parveen
# 2  103   ayesha
# 3  104    hakim
#    eid    ename
# 0  101      abu
# 1  102  parveen
# 2  103   ayesha
# 3  104    hakim

# %%
Num1 = [101,102,103,104]
print(Num1, type(Num1))
f1 = pd.Series(Num1)
print(f1, type(f1))

name1 = ['abu','parven','ayesha','hakim']
print(name1, type(name1))

df1 = pd.DataFrame({'eid':f1, 'ename':f2})
print(df1)
df1
# Out:
# [101, 102, 103, 104] <class 'list'>
# 0    101
# 1    102
# 2    103
# 3    104
# dtype: int64 <class 'pandas.core.series.Series'>
# ['abu', 'parven', 'ayesha', 'hakim'] <class 'list'>
#    eid  ename
# 0  101    101
# 1  102    102
# 2  103    103
# 3  104    104
#    eid  ename
# 0  101    101
# 1  102    102
# 2  103    103
# 3  104    104

# %%
df1
# Out:
#    eid  ename
# 0  101    101
# 1  102    102
# 2  103    103
# 3  104    104

# %%
data1 = ({'eid':[101,102,103,104],'ename':['abu','parven','ayesha','hakim']})
df2 = pd.DataFrame(data1)
df2
# Out:
#    eid   ename
# 0  101     abu
# 1  102  parven
# 2  103  ayesha
# 3  104   hakim

# %%
data1 = ({'eid':[101,102,103,104],'ename':['abu','parven','ayesha','hakim']})
print(data1,type(data1))
# Out:
# {'eid': [101, 102, 103, 104], 'ename': ['abu', 'parven', 'ayesha', 'hakim']} <class 'dict'>

# %%
df2
type(df2)
# Out:
# pandas.core.frame.DataFrame

# %%
print(type(df2))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df2
# Out:
#    eid   ename
# 0  101     abu
# 1  102  parven
# 2  103  ayesha
# 3  104   hakim

# %% [markdown]
# ## Assign indices to the Rows

# %%
df2 = pd.DataFrame(data1)
df2
# Out:
#    eid   ename
# 0  101     abu
# 1  102  parven
# 2  103  ayesha
# 3  104   hakim

# %%
#data1 = ({'eid':[101,102,103,104],'ename':['abu','parven','ayesha','hakim']})
df2 = pd.DataFrame(data1, index=['r1','r2','r3','r4'])
df2
# Out:
#     eid   ename
# r1  101     abu
# r2  102  parven
# r3  103  ayesha
# r4  104   hakim

# %%
Data_1 = ({'eid':[101,102,103],'ename':['Abu','parveen','ayeshu']})
print(Data_1,type(Data_1))
df1 = pd.DataFrame(Data_1)
df1
df1 = pd.DataFrame(Data_1, index=['r1','r2','r3'])
df1
# Out:
# {'eid': [101, 102, 103], 'ename': ['Abu', 'parveen', 'ayeshu']} <class 'dict'>
#     eid    ename
# r1  101      Abu
# r2  102  parveen
# r3  103   ayeshu

# %% [markdown]
# # Access elements of dataframe using loc and iloc

# %%
df1.loc['r2']
# Out:
# eid          102
# ename    parveen
# Name: r2, dtype: object

# %%
df1.loc[['r2']]
# Out:
#     eid    ename
# r2  102  parveen

# %%
df1['eid']
# Out:
# r1    101
# r2    102
# r3    103
# Name: eid, dtype: int64

# %%
df1['ename']
# Out:
# r1        Abu
# r2    parveen
# r3     ayeshu
# Name: ename, dtype: object

# %%
df1.loc[['r3']]
# Out:
#     eid   ename
# r3  103  ayeshu

# %%
import pandas as pd
Data_1 = ({'eid':[101,102,103],'ename':['Abu','parveen','ayeshu']})
print(Data_1,type(Data_1))
df1 = pd.DataFrame(Data_1)
df1
# Out:
# {'eid': [101, 102, 103], 'ename': ['Abu', 'parveen', 'ayeshu']} <class 'dict'>
#    eid    ename
# 0  101      Abu
# 1  102  parveen
# 2  103   ayeshu

# %%
df1
# Out:
#    eid    ename
# 0  101      Abu
# 1  102  parveen
# 2  103   ayeshu

# %%
df1 = pd.DataFrame(Data_1, index = ['r1','r2','r3'])
df1
# Out:
#     eid    ename
# r1  101      Abu
# r2  102  parveen
# r3  103   ayeshu

# %%
df1.loc['r1']
# Out:
# eid      101
# ename    Abu
# Name: r1, dtype: object

# %%
df1.loc[['r1']]
# Out:
#     eid ename
# r1  101   Abu

# %%
df1['eid']
# Out:
# r1    101
# r2    102
# r3    103
# Name: eid, dtype: int64

# %%
df1[['eid','ename']]
# Out:
#     eid    ename
# r1  101      Abu
# r2  102  parveen
# r3  103   ayeshu

# %%
df1.loc[:,'eid']
# Out:
# r1    101
# r2    102
# r3    103
# Name: eid, dtype: int64

# %%
df1.iloc[0,0] # 0- row index position, 0-columns index position
# Out:
# 101

# %%
df1.iloc[0,1]
# Out:
# 'Abu'

# %%
df1.iloc[2,0]  # 2- row index position, 0-columns index position
# Out:
# 103

# %%
df1.iloc[2,1]  # 2- row index position, 1-columns index position
# Out:
# 'ayeshu'

# %% [markdown]
# ## Filter elements of dataframe

# %%
df1[df1['ename']=='Abu']
# Out:
#     eid ename
# r1  101   Abu

# %%
#   r3   103    ayeshu     
df1[df1['eid']==103]
# Out:
#     eid   ename
# r3  103  ayeshu

# %%
df1[df1['eid']>101]
# Out:
#     eid    ename
# r2  102  parveen
# r3  103   ayeshu

# %%
df1[df1['eid']<103]
# Out:
#     eid    ename
# r1  101      Abu
# r2  102  parveen

# %%
df1[df1['eid']>101]
# Out:
#     eid    ename
# r2  102  parveen
# r3  103   ayeshu

# %%
df1[df1['eid']%2==0]
# Out:
#     eid    ename
# r2  102  parveen

# %%
Data2 = ({'Name':['Mahendran','Abu','anandh','Madhi'],'age':[30,27,34,35]})
print(Data2)
# Out:
# {'Name': ['Mahendran', 'Abu', 'anandh', 'Madhi'], 'age': [30, 27, 34, 35]}

# %%
df1 = pd.DataFrame(Data2)
df1
# Out:
#         Name  age
# 0  Mahendran   30
# 1        Abu   27
# 2     anandh   34
# 3      Madhi   35

# %%
df1 = pd.DataFrame(Data2, index = ['r1','r2','r3','r4'])
df1
# Out:
#          Name  age
# r1  Mahendran   30
# r2        Abu   27
# r3     anandh   34
# r4      Madhi   35

# %%
df1[df1['age']<34]
# Out:
#          Name  age
# r1  Mahendran   30
# r2        Abu   27

# %%
df1.loc['r2']
# Out:
# Name    Abu
# age      27
# Name: r2, dtype: object

# %%
df1.loc[['r2']]
# Out:
#    Name  age
# r2  Abu   27

# %%
df1.iloc[[0]]
# Out:
#          Name  age
# r1  Mahendran   30

# %%
df1.iloc[1,1]
# Out:
# 27

# %% [markdown]
# ## Load data into dataframe from multiple sources

# %%
df2 = pd.read_csv('file1.txt')
df2
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
df2 = pd.read_csv('file1.csv')
df2
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
df2 = pd.read_json('file1.json')
df2
# Out:
#    eid    ename
# 0  101     Sree
# 1  102      Sai
# 2  103  Kishore

# %%
url = "https://support.staffbase.com/hc/en-us/article_attachments/360009159392/access-code.csv"

df3 = pd.read_csv(url, sep=";")
df3
# Out:
#    Identifier First name Last name
# 0      901242     Rachel    Booker
# 1      207074      Laura      Grey
# 2      408129      Craig   Johnson
# 3      934600       Mary   Jenkins
# 4      507916      Jamie     Smith

# %%
df3.index = ['r1','r2','r3','r4','r5']
df3
# Out:
#     Identifier First name Last name
# r1      901242     Rachel    Booker
# r2      207074      Laura      Grey
# r3      408129      Craig   Johnson
# r4      934600       Mary   Jenkins
# r5      507916      Jamie     Smith

# %%
df3.loc[['r1']]
# Out:
#     Identifier First name Last name
# r1      901242     Rachel    Booker

# %%
df3.iloc[[0]]
# Out:
#     Identifier First name Last name
# r1      901242     Rachel    Booker

# %%
url = "https://en.wikipedia.org/wiki/Administrative_divisions_of_India"
df4 = pd.read_html(url)
df4
# Out:
# [    0                                                  1
#  0 NaN  This article possibly contains original resear...,
#                                                      0
#  0             This article is part of a series on the
#  1                                   Politics of India
#  2   Constitution and law Constitution of India Fun...
#  3   Government President of India Droupadi Murmu V...
#  4   Parliament Parliament of India Lok Sabha Speak...
#  5   Judiciary Supreme Court of India Chief Justice...
#  6   Elections and political parties Presidential e...
#  7   Administrative divisions States Andhra Pradesh...
#  8   Federalism Executive Governors (List) Lieutena...
#  9   Foreign relations Ministry of External Affairs...
#  10                       India portal Other countries
#  11                                                vte,
#      0   1   2   3                                                  4   \
# ...

# %%
df4 = pd.read_html(url, sep=";")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[91], line 1
# ----> 1 df4 = pd.read_html(url, sep=";")
#
# TypeError: read_html() got an unexpected keyword argument 'sep'

# %%
type(df4)
# Out:
# list

# %%
type(df4[2])
# Out:
# pandas.core.frame.DataFrame

# %%
df5 = df4[4]
df5
# Out:
#                 State    ISO Vehicle code           Zone  \
# 0      Andhra Pradesh  IN-AP           AP       Southern
# 1   Arunachal Pradesh  IN-AR           AR  North-Eastern
# 2               Assam  IN-AS           AS  North-Eastern
# 3               Bihar  IN-BR           BR        Eastern
# 4        Chhattisgarh  IN-CG           CG        Central
# 5                 Goa  IN-GA           GA        Western
# 6             Gujarat  IN-GJ           GJ        Western
# 7             Haryana  IN-HR           HR       Northern
# 8    Himachal Pradesh  IN-HP           HP       Northern
# 9           Jharkhand  IN-JH           JH        Eastern
# 10          Karnataka  IN-KA           KA       Southern
# 11             Kerala  IN-KL           KL       Southern
# 12     Madhya Pradesh  IN-MP           MP        Central
# 13        Maharashtra  IN-MH           MH        Western
# 14            Manipur  IN-MN           MN  North-Eastern
# ...

# %%
df5.iloc[:,0:6]
# Out:
#                 State    ISO Vehicle code           Zone  \
# 0      Andhra Pradesh  IN-AP           AP       Southern
# 1   Arunachal Pradesh  IN-AR           AR  North-Eastern
# 2               Assam  IN-AS           AS  North-Eastern
# 3               Bihar  IN-BR           BR        Eastern
# 4        Chhattisgarh  IN-CG           CG        Central
# 5                 Goa  IN-GA           GA        Western
# 6             Gujarat  IN-GJ           GJ        Western
# 7             Haryana  IN-HR           HR       Northern
# 8    Himachal Pradesh  IN-HP           HP       Northern
# 9           Jharkhand  IN-JH           JH        Eastern
# 10          Karnataka  IN-KA           KA       Southern
# 11             Kerala  IN-KL           KL       Southern
# 12     Madhya Pradesh  IN-MP           MP        Central
# 13        Maharashtra  IN-MH           MH        Western
# 14            Manipur  IN-MN           MN  North-Eastern
# ...

# %%
df_zone = df4[3]
df_zone
# Out:
#                          Zone  \
# 0          South Culture Zone
# 1  South Central Culture Zone
# 2          North Culture Zone
# 3  North Central Culture Zone
# 4           East Culture Zone
# 5     North East Culture Zone
# 6           West Culture Zone
#
#                                         Zonal Centre  \
# 0  South Zone Cultural Centre, Thanjavur, Tamil Nadu
# 1  South-Central Zone Cultural Centre, Nagpur, Ma...
# 2        North Zone Cultural Centre, Patiala, Punjab
# 3  North-Central Zone Cultural Centre, Prayagraj,...
# 4    East Zone Cultural Centre, Kolkata, West Bengal
# 5  North East Zone Cultural Centre, Dimapur, Naga...
# 6      West Zone Cultural Centre, Udaipur, Rajasthan
#
#                                               Extent
# 0  Andaman and Nicobar Islands, Andhra Pradesh, K...
# 1  Andhra Pradesh, Chhattisgarh, Goa, Karnataka, ...
# 2  Chandigarh, Haryana, Himachal Pradesh, Jammu a...
# 3  Bihar, Delhi, Haryana, Madhya Pradesh, Rajasth...
# ...
